# %% [markdown]
# <a href="https://colab.research.google.com/github/roziyoussouf8-wq/programmation/blob/main/Copie_de_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pour installer une bibliothèque Python, utilisez la commande `!pip install` suivie du nom de la bibliothèque. Par exemple, pour installer `pandas` :

# %%
# !pip install pandas

# %% [markdown]
# Vous pouvez également spécifier une version spécifique de la bibliothèque ou installer plusieurs bibliothèques en même temps :

# %%
# !pip install numpy==1.23.0 matplotlib scikit-learn
# Out:
# ...
#   Using cached numpy-1.23.0.tar.gz (10.7 MB)
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

# Affichage d'un message pour confirmer l'importation
print("Bibliothèques importées avec succès !")
